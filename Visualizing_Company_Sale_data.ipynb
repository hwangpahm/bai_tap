# %% [markdown]
# # Visualizing Company Sale data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/thieu1995/csv-files/blob/main/data/matplotlib/company_sales_data.csv).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/matplotlib/company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ### Exercise 1: Read Total profit of all months and show it using a line plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/01.png?raw=1)

# %%
df.plot(y='total_profit', figsize=(9,5))
# Out:
# <Axes: >

# %% [markdown]
# ### Exercise 2: Get total profit of all months and show line plot with the following Style properties
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/02.png?raw=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt


total_profit = df['total_profit'].tolist()
monthnumber = df['month_number'].tolist()

plt.plot(monthnumber, total_profit, label='Profit data of last year', color='r', marker='o', markerfacecolor='k', linestyle='--', linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.xticks(monthnumber)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it  using a multiline plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/03.png?raw=1)

# %%
#df.plot.line(y=['facecream', 'facewash','toothpaste','bathingsoap','shampoo','moisturizer'], figsize=(9,6))
facecream = df['facecream'].tolist()
facewash = df['facewash'].tolist()
toothpaste =df['toothpaste'].tolist()
bathingsoap=df['bathingsoap'].tolist()
shampoo=df['shampoo'].tolist()
moisturizer=df['moisturizer'].tolist()
monthnumber=df['month_number'].tolist()
plt.xticks(monthnumber)
plt.title('sales data')
plt.xlabel('month number')
plt.ylabel('sales units in number')
plt.plot(facewash,label='face wash sales data' ,color='orange', marker='o', linestyle='-', linewidth=4)
plt.plot(toothpaste,label='toothpaste sales data', color='green', marker='o', linestyle='-', linewidth=4)
plt.plot(bathingsoap,label='bathing soap sales data',color='red' ,marker='o', linestyle='-', linewidth=4)
plt.plot(shampoo,label='shampoo sales data', color='purple', marker='o', linestyle='-', linewidth=4)
plt.plot(facecream,label='face cream sales data', color='blue', marker='o', linestyle='-', linewidth=4)
plt.plot(moisturizer,label ='moisturizer sales data ', color='brown', marker='o', linestyle='-', linewidth=4)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/04.png?raw=1)

# %%
import matplotlib.style
import matplotlib as mpl
plt.style.available
plt.style.use('default')
plt.plot()
# Out:
# []

# %%
fig,ax = plt.subplots()
ax.grid(color='gray', linewidth=1, linestyle='dashed')
ax.set_title('tooth paste sales data')

ax.scatter(monthnumber,toothpaste,label='Tooth paste Sales data',s=100)

plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend(loc='upper left')

# %% [markdown]
# ### Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/05.png?raw=1)

# %%
fig,ax = plt.subplots()
ax.grid(True, linewidth=1, linestyle='dashed')
a=plt.xticks(monthnumber)
m=np.array(monthnumber)
cream=plt.bar(m-0.3,facecream,color='blue',width=0.3,label='face cream')
wash= plt.bar(monthnumber,facewash,color='orange',width=0.3,label='face wash')
plt.xlabel(' month number')
plt.ylabel('sales units in number')
plt.title('face wash and face cream sales data')
plt.legend(loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2a032448b6eb> in <cell line: 4>()
#       2 ax.grid(True, linewidth=1, linestyle='dashed')
#       3 a=plt.xticks(monthnumber)
# ----> 4 m=np.array(monthnumber)
#       5 cream=plt.bar(m-0.3,facecream,color='blue',width=0.3,label='face cream')
#       6 wash= plt.bar(monthnumber,facewash,color='orange',width=0.3,label='face wash')
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %%
fig,ax = plt.subplots()
ax.grid(True, linewidth=1, linestyle='dashed')
plt.xticks(monthnumber)
plt.xlabel('month number')
plt.ylabel('sales units in number')
plt.title('bathingsoap sales data')
ax.bar(monthnumber,bathingsoap, color='b', width=0.8)
plt.savefig('123.png')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %%
plt.hist(total_profit,color='blue',label='profit data')
plt.legend(loc='upper left')
plt.xlabel(' profit range in dollar')
plt.ylabel('actual profit in dollar')
plt.title('profit data')
plt.yticks([0,1,2,3,4,5])
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %%
a =df['toothpaste'].sum()
b=df['facewash'].sum()
c=df['facecream'].sum()
d=df['moisturizer'].sum()
e=df['shampoo'].sum()
f=df['bathingsoap'].sum()
plt.title('sales data')
labels = ["toothpaste", "Bafacewashnanas", "facecream", "moisturizer","shampoo","bathingsoap"]
x=[a,b,c,d,e,f]
plt.pie(x, labels = labels, startangle = 180, autopct='%1.2f%%')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %%
fig,(ax1,ax2)=plt.subplots(2,1)
plt.xticks(monthnumber)
ax1.plot(monthnumber,bathingsoap, label='sales data of a facecream', color='black', marker='o', markerfacecolor='black', linestyle='-', linewidth=3)
ax1.set_xticks(monthnumber)
ax1.set_xticklabels([])
ax1.set_title('sales data of a facecream')
ax2.plot(monthnumber,facewash,label='sales of a facewash',color='red', marker='o', markerfacecolor='red', linestyle='-', linewidth=3)
ax2.set_title('sales of a facewash')
plt.xlabel('month number')
plt.ylabel('sales units in number')
# Out:
# Text(0, 0.5, 'sales units in number')

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %%
plt.style.use("default")

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthnumber, facecream, facewash, toothpaste, 
              bathingsoap, shampoo, moisturizer, 
              colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)
